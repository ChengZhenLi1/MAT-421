# %% [markdown]
# <a href="https://colab.research.google.com/github/ChengZhenLi1/MAT-421/blob/main/HW_for_module_E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Continunity and Differentiation**
#
#
# **1: Continunity**
# (1) Limits of a function:
#
# Let f : D to R to be a real-valued function on D that is a subset of R^d. Then the function f is said to have a limit L as x is approaching to a if for any b>0, there exists a c>0 such that |f(x)-L| < c for all a that belong to the union of D and B_c(a)\{a}
#
# Example:
#
# let function f(x)= (x^2-4)/(x-2)
#
# Then, simplifying (x-2) on the top and bottle, there is only (x+2) left.
#
# Then, as x approaches to 2, the limit of this function is 4.
#
#
# (2) Continuous function:
#
# Let a real valued function f : D to R where D is a subset of R^d. Then f is said to be continuous at a that belongs to D if the limit of f(x) as x is approaching to a is equal to f(a)
#
# Example: Let f(x)=3x+2 and let a=4
#
# f(4)=12+2=14
#
# the limit of f(x) as x is approaching to 4 is 3(4)+2=12
#
# 14=14, therefore the limit of limit of f(x) as x is approaching to 4 equals to f(4). Therefore, the function f(x)=3x+2 is continous.
#
#
# (3) Compisition of continuous functions:
#
# Let f:D_1 to R^m, where D_1 is a subset of R^d, and let g: D_2 to R^p, where D_2 is an subset of R^m. If f(x) is continuous at a and g(f(x)） is continuous. Then g of f is said to be continuous at x
#
# Example:
#
# Let f(x)=x^3+2 and g(b)= (4-a)/5
#
# Let a=4, the limit of f(x) as x is approaching to x is 66, g(f(4))=g(66)=62/5
#
# The limit of g as b is approaching to 66 is g(66)=62/5
#
# 62/5=62/5 indicates that g(f(4)) indicates that g is continous at f(4).
#
# Therefore, g(f(x)) is continuous at b=4.
#
#
# (4) Extremum: Suupose a real-valued function f : D to R is defined on set D
#
# f is said to have a maximum value A at x_1 if f(x_1)=A and A is the greatest value of the range of f(x)
#
# f is said to have a minimum value B at x_2 if f(x_2)=b and B is the least value of the range of f(x)
#
# f is said to have a minimum value and maximum value if its interval is a closed, bounded interval and f is continuou in this interval.
#
#
# **Differentiation**
#
# (1) Let f and g have derivatives at x and let A and B be constants
#
# Then (d/dx)[Af(x)+Bg(x)]= A(d/dx)(f(x))+B(d/dx)(B(x))
#
# Example:
#
# Let f(x)=2x^2 and g(x)=3x^5
#
# Then (d/dx)[2x^2+3x^5]=(d/dx)(2x^2)+(d/dx)(3x^5)=4x+15x^4
#
# (2) Let f:D to R with D is a subset of R and let x_0 be in the set D where f^'(x_0) exists. if f^'(x_0)>0, then:
#
# f(x)>f(x_0) if x>x_0
#
# f(x)< f(x_0) if x<x_0
#
# (3) Let f: [a,b] to R be a continuous function and assume that its derivative exists on the interval (a,b) then there exists an value c in the interval such that f^'(c)=0.
#
# (4) If f is a continuous function on the interval [a,b] and its derivatives exists on the interval, then there exists a value c in the interval (a,b) such that f(b)=f(a)+(b-a)f^(c)
#
# (5) Partial derivative: Let f: D to R where D is an subset of R^d and let x_0 be in the set D. Then the partial derivative of f at x_0 with respect to x_i is
#
# [(∂f(x_0))/∂x_i]= the limit [f(x_0+h*e_i)-f(x_0)]/h as h is approaching to 0.
#
# (6) Let f= (f_1, ... , f_m): D to R and let x_0 be a point in set D.
#
# Then the jacobian of f at x_0 is the d by m matrix
#
# J_f(x_0)=[(∂ f1(x0)/∂ x1), ... , (∂ fm(x0)/∂ x1) ; (∂f1(x0)/∂xd), ... , (∂fm(x0)/∂xd)]
#
# (7) Chain Rule: Let function f: D to R and D is a subset of R. Let function g: D to R. If the derivative of f is continuous at x_0 and x_0 is in set D. And the derivative of g is continuous at f(x_0). The J_(g◦f)(x_0) = J_g(f(x_0)) * Jf(x0).
#
# (8) Directional derivative:
#
# Let function f: D to R and D is an subset of R. Let x_0 be in the set of D and Let V be a d by 1 vector. Then the directional derivative of f at x_0 in the direction of vector V is [(∂f(x_0))/∂v]= the limit of [f(x_0 +hv)− f(x0)]/h as h approaches to 0.
#
# (9) Directional Derivative from Gradient.
#
# Let f: D to R where D is a subset of R. Let x_0 be in the set D and Let V be a d by 1 unit vector. If the derivative of f is coutinuous at x_0, then the directional derivative of f at x_0 in the direction of V is given by (∂f(x_0)/∂v) = Jf(x0)v = ∇f(x0)^T*v.
#
# (10) Summetry of the Hessian:
#
# Let function f : D to R and D is a subset of R. Let x_0 be in the set of D. Assume f is twice continuously differentiable at x_O. Then for all i does equal to j. (∂2*f(x_0))/(∂_xj * ∂_xi) = (∂^2*f(x0))/(∂_xi*∂x_j)
#
# (11) Taylor's theorem:
#
# Let function f:D to R and D is a subset of R. Suppose f has a m times continuous derivativr on [a,b].
#
# Then f(b)= f(a)+(b-a)f^'(a)+(1/2)(b-a)^2f''(a)+ ... + [(b-a)^(m-1)/(m-1)!]*f^(m-1)(a)+R_m
#
#
# (12) Multivariate taylor:
#
# Let f: D to R where D is a subset of R. Let X be in the set D and δ>0. If f is three times continuously differentiable on  B_δ(x_0). Then for any x that belongs to  B_δ(x_0).
#
# f(x)=f(x_0)++∇f(x0)^T*p+(1/2) * p^T * Hf(x0)p+O(|p||^3)
#
# (13) Local minimizer:
#
# Let f: R^d to R. Then the point x that's in R^d is a local minimizer of f over R^d if there is δ > 0 such that f(x)>=f(x^*)  ∀x ∈ B_δ(x^∗) \{ x^∗}
#
# (14) Descent Direction:
#
# Let f: R^d to R. A vector v is a descnt direction for f at x_0 if there exists a^*>0 such that f(x_0 + a * v)<f(x_0)
#
# (15) Existence of a descent direction: Let f: R^d to R. Let its derivative be continuous at x_0 and assume ∇f(x_0) doesn't equal to 0. Then f has a descent direction at x_0
#
# (16) A square symmetric d by d matrix H is positive semi-definited if x^T*H*x is greater or equal to 0 for any vector x that's in R^d
#
# (17) Second-order sufficient condition:
#
# Let f: R^d to R be twicw continuoutly differentiable on R^d. If ∇f(x_0) = 0 and H_f(x_0) is positive definite, then x_0 is a strict local minimizer
#
# (18) Convex function:
#
# A function f: R^d to R is convex if for all x and y that belong to R^d and all a that's in the interval  [0,1], f((1-a)x+ay)<=(1-a)f(x)+af(y)
